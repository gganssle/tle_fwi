# %%
using Seismic, PyPlot

# %%
old_vel, old_vel_h = SeisRead("../vel/vel_2");
print(minimum(old_vel),"\n")
print(maximum(old_vel))
# Out:
# 2000.0
# 4000.0

# %%
SeisPlot(old_vel[:,:,1], cmap="plasma")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f1a78c09160>)
# PyObject <matplotlib.image.AxesImage object at 0x7f1a78b2c710>

# %%
new_vel, new_vel_h = SeisRead("../fwi/updated_vel");
print(minimum(new_vel),"\n")
print(maximum(new_vel))
# Out:
# 64001.6
# 128003.2

# %%
SeisPlot(new_vel[:,:,1],cmap="plasma")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f1a78aa03c8>)
# PyObject <matplotlib.image.AxesImage object at 0x7f1a789a5d68>
