# %%
using Seismic, PyPlot

# %%
d1,h1 = SeisRead("../dat/vel_correct");

# %%
SeisPlot(d1[:,:,50], cmap = "viridis_r")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f00649efda0>)
# PyObject <matplotlib.image.AxesImage object at 0x7f006497b828>

# %%
d2,h2 = SeisRead("../dat/vel_incorrect");
SeisPlot(d2[:,:,1], cmap = "hot")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f0068f8fb70>)
# PyObject <matplotlib.image.AxesImage object at 0x7f00687e3eb8>
