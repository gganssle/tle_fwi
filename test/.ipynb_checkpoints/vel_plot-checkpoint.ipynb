# %%
using Seismic, PyPlot

# %%
d1,h1 = SeisRead("../dat/vel_correct");

# %%
SeisHeaderInfo("../dat/vel_correct");
# Out:
# LoadError: SystemError: opening file NULL: No such file or directory
# while loading In[3], in expression starting on line 1
#
#  in open at ./iostream.jl:90
#  in open at iostream.jl:99
#  in SeisHeaderInfo at /home/gram/.julia/v0.4/Seismic/src/Utils/SeisHeaderInfo.jl:11

# %%
SeisPlot(d1[:,:,1])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6046fd8f90>)
# PyObject <matplotlib.image.AxesImage object at 0x7f6046e75050>

# %%
d2,h2 = SeisRead("../dat/vel_incorrect");
SeisPlot(d2[:,:,1])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f60445ad2d0>)
# PyObject <matplotlib.image.AxesImage object at 0x7f60445be4d0>
