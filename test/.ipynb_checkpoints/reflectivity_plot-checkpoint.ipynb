# %%
using Seismic, PyPlot

# %%
d,h = SeisRead("../mod/refl");
SeisPlot(d[:,:,1])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f55214545d0>)
# PyObject <matplotlib.image.AxesImage object at 0x7f550ac99f10>

# %%
d,h = SeisRead("../mod/image");

SeisPlot(d[:,:,1],cmap="seismic")
PyPlot.colorbar(orientation="vertical")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f550ac50110>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f550ac50110>)
# PyObject <matplotlib.colorbar.Colorbar instance at 0x7f550aa9bcb0>
