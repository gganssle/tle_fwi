# %%
using Seismic, PyPlot

# %%
d,h = SeisRead("../mod/refl");
SeisPlot(d[:,:,1])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f81402b3650>)
# PyObject <matplotlib.image.AxesImage object at 0x7f8140118410>

# %%
d,h = SeisRead("../mod/image");
SeisPlot(d[:,:,20],cmap="PuOr")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f813fd03fd0>)
# PyObject <matplotlib.image.AxesImage object at 0x7f813fc8ac90>
