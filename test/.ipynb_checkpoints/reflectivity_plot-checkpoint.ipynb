# %%
using Seismic, PyPlot

# %%
d,h = SeisRead("../mod/refl");
SeisPlot(d[:,:,1])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fe92fb44128>)
# PyObject <matplotlib.image.AxesImage object at 0x7fe92f9fb6d8>

# %%
d,h = SeisRead("../mod/image");

SeisPlot(d[:,:,30],cmap="seismic")
PyPlot.colorbar(orientation="vertical")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fe92f9ef390>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x7fe92fbd3eb8>
