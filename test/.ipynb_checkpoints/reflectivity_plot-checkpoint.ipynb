# %%
using Seismic, PyPlot

# %%
d,h = SeisRead("../mod/refl");
SeisPlot(d[:,:,1])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6d48fa45d0>)
# PyObject <matplotlib.image.AxesImage object at 0x7f6d327ebf10>

# %%
d,h = SeisRead("../mod/image");

SeisPlot(d[:,:,30],cmap="seismic")
PyPlot.colorbar(orientation="vertical")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6d323638d0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6d323638d0>)
# PyObject <matplotlib.colorbar.Colorbar instance at 0x7f6d321d10e0>
