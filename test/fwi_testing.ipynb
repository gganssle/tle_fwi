# %%
using Seismic, PyPlot

# %%
d, h = SeisRead("../fwi/updated_vel");

# %%
SeisPlot(d[:,:,10])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fc47d7f0fd0>)
# PyObject <matplotlib.image.AxesImage object at 0x7fc47d714198>
