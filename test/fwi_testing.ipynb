# %%
using Seismic, PyPlot

# %%
old_vel, old_vel_h = SeisRead("../dat/vel_incorrect");
print(minimum(old_vel),"\n")
print(maximum(old_vel))
# Out:
# 2000.0
# 4000.0

# %%
SeisPlot(old_vel[:,:,1], cmap="plasma")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7faf46378450>)
# PyObject <matplotlib.image.AxesImage object at 0x7faf43590790>

# %%
new_vel, new_vel_h = SeisRead("../dat/updated_vel");
print(minimum(new_vel),"\n")
print(maximum(new_vel))
# Out:
# 2000.0
# 4000.0

# %%
SeisPlot(new_vel[:,:,1],cmap="plasma")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7faf432d2b10>)
# PyObject <matplotlib.image.AxesImage object at 0x7faf4340d090>

# %%
new_vel[:,:,1]
# Out:
# 20x5 Array{Float32,2}:
#  2000.0  2000.0  2000.0  2000.0  2000.0
#  2000.0  2000.0  2000.0  2000.0  2000.0
#  2000.0  2000.0  2000.0  2000.0  2000.0
#  2000.0  2000.0  2000.0  2000.0  2000.0
#  2000.0  2000.0  2000.0  2000.0  2000.0
#  2000.0  2000.0  2000.0  2000.0  2000.0
#  3000.0  3000.0  3000.0  3000.0  3000.0
#  3000.0  3000.0  3000.0  3000.0  3000.0
#  3000.0  3000.0  3000.0  3000.0  3000.0
#  3000.0  3000.0  3000.0  3000.0  3000.0
#  3000.0  3000.0  3000.0  3000.0  3000.0
#  3000.0  3000.0  3000.0  3000.0  3000.0
#  3000.0  3000.0  3000.0  3000.0  3000.0
#  3500.0  3500.0  3500.0  3500.0  3500.0
#  3500.0  3500.0  3500.0  3500.0  3500.0
#  3500.0  3500.0  3500.0  3500.0  3500.0
#  3500.0  3500.0  3500.0  3500.0  3500.0
#  4000.0  4000.0  4000.0  4000.0  4000.0
#  4000.0  4000.0  4000.0  4000.0  4000.0
#  4000.0  4000.0  4000.0  4000.0  4000.0
