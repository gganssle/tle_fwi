# %%
using Seismic, PyPlot

# %%
d, h = SeisRead("../fwi/updated_vel");

# %%
SeisPlot(d[:,:,10])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f1d716750f0>)
# PyObject <matplotlib.image.AxesImage object at 0x7f1d71e286d8>
